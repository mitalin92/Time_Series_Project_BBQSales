# %% [markdown]
# Sales Over Time

# %%
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df1 = read_csv("climate_data.csv")
df2 = read_csv("barbecue_sauce_sales.csv")

merged_df = pd.merge(df1, df2, on="date", how ="inner")

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'], errors='coerce')

merged_df['year'] = merged_df['date'].dt.year

sales_per_year = merged_df.groupby('year')['amount'].sum().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(sales_per_year['year'], sales_per_year['amount'], marker='o', linewidth=2, color='steelblue')
plt.title('Sales Over Time', fontsize=14)
plt.xlabel('Time')
plt.ylabel(' Sales')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The graph shows total sales from 2020 to 2025, with fluctuations rather than a steady increase or decrease,
# the trend starts moderately high in 2020, dips in 2021 to 2022, then rises sharply in 2023 before falling again in 2024 to 2025.
#
# Ananlysis
#
# 2020 to 2022
#
#  The declining  in sales could be due the impact of COVID-19 restrictions, which limited social gatherings and outdoor events and the less favorable weather for outdoor activities
#
#  2023
#
# The high sales sales in 2023 is likely due to favourable weather patterns experienced in that year and the post-COVID social recovery, as people resumed outdoor gatherings and celebrations.
#
#  2024
#
# A stable year, possibly reflecting consistent climate and strong consumer demand, but not execptional condition for 2023,alongside lingering shifts in consumer habits formed during the COVID-19 period.
#
# 2025
#
# The declined is likely due to weather regression, less sunshine or more rain impacting barbecue related behavior and possible long term economic or lifestyle adjustments following the COVID-19 pandemic.
